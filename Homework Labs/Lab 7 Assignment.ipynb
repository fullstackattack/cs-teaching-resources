# %%
# ============================
# Lab 7: More Plotly Express Visualizations
# ============================
#
# In this lab, you’ll extend what you learned in Lab 6 by creating
# more advanced visualizations using Plotly Express.
#
# Before starting:
# import plotly.express as px
# import pandas as pd
# import numpy as np
# ============================
#
# ----------------------------
# Part 1: Multi-Line Charts
# ----------------------------
#
# 1. Create this DataFrame of monthly cookie sales:
# cookies = pd.DataFrame({
#     'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'],
#     'Chocolate Chip': [120, 130, 140, 160, 150, 170],
#     'Oatmeal Raisin': [90, 95, 100, 110, 105, 115],
#     'Sugar Cookie': [60, 70, 65, 80, 75, 85]
# })
#
# 2. Use px.line() to plot ALL THREE cookie types on the same chart.
#
#
# 3. Add chart design elements:
#    - Add markers by setting:   markers=True
#    - Change the template to 'plotly_dark' 
#    - Add axis titles using fig_update_layout:
#
# 4. Reflection Questions:
#    - Which cookie type increased the most over time?
#    - How does having multiple lines on the same chart help you compare trends?
#    - What formatting choices made your chart easier to read?

# %%
# ----------------------------
# Part 2: Multi-Variable Scatter Plots
# ----------------------------
#
# 6. Create this dataset showing cookie shop data:
# shop = pd.DataFrame({
#     'Store': ['Downtown', 'Uptown', 'Suburb', 'Mall', 'Airport'],
#     'Sales': [400, 380, 300, 450, 500],
#     'Customers': [200, 190, 160, 230, 260],
#     'Average Rating': [4.6, 4.4, 4.1, 4.8, 4.9]
# })
#
# 7. Make a scatter plot of Sales vs. Customers.
#    - Use px.scatter(shop, x='Customers', y='Sales')
#    - Color the points by "Store"
#    - Size the points by "Average Rating"
#    - Add a title and axis labels
#
# 8. Optional Extension:
#    Add a trendline to the scatter plot (you must remove the color grouping):
#
# 9. Challenge:
#    Add hover data so that when you mouse over each point, it shows:
#        hover_data=['Store', 'Average Rating']
#
#    Try different templates:
#        template='seaborn'
#        template='plotly_dark'
#        template='ggplot2'
#
# 10. Reflection:
#     - What relationship do you notice between customers and sales?
#     - Does the trendline support what you see in the scatter plot?
#     - How does bubble size (ratings) help communicate information?
#     - What formatting choices make a visualization more readable?
#     - When would you use a line chart vs. a scatter plot?
#     - How can multiple visual encodings (color, size, markers) help explain data?
