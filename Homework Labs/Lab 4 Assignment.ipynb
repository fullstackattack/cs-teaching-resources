# %%
#============================
#Lab 4: Functions, Arrays, and Tables
#============================
#
#In this lab, you’ll combine NumPy operations with writing your own functions.
#You will practice:
#
#- Writing functions with 1, 2, and 3 parameters
#- Using NumPy to sort, filter, and search arrays
#- Displaying results in tables
#
#Before starting:
#import numpy as np
#import pandas as pd
#
#----------------------------
#Part 1: Functions with 1 Parameter
#----------------------------
#
#1. Write a function square_elements(arr) that takes a NumPy array and
#returns a new array with each element squared.
#Test it with np.array([1, 2, 3, 4, 5]).
#
#2. Write a function is_even(x) that returns True if x is even,
#and False if not. Test it with several values. Hint: Use modulo.
#
#3. Write a function sort_array(arr) that takes a 1D array and
#prints both the original and sorted version.

# %%
#----------------------------
#Part 2: Functions with 2 Parameters
#----------------------------
#
#4. Write a function between(arr, low, high) that returns the values
#from arr that are greater than low and less than high.
#Test with np.arange(0, 21), low=5, high=15.
#
#5. Write a function replace_above(arr, threshold) that replaces all values
#in arr greater than threshold with -1. Test it with np.arange(0, 21).
#6. Write a function compare_scores(score1, score2) that prints
#which score is higher, or if they are equal.

# %%
#----------------------------
#Part 3: Functions with 3 Parameters
#----------------------------
#
#7. Write a function insert_value(arr, value, side) that uses
#np.searchsorted to find where value would be inserted into arr.
#Print the index. Test with arr = np.array([5, 10, 15, 20, 25]), value=12, side='left'.
#
#8. Write a function make_dataframe(names, scores, cutoff) that creates
#a pandas DataFrame with columns "Name" and "Score". Then filter
#the table to show only students with scores >= cutoff.
#Test with names = ["Alice", "Bob", "Carlos", "Diana"],
#scores = [85, 92, 78, 90], cutoff=80.
#
#9. Write a function add_pass_fail(names, scores, cutoff) that builds
#a DataFrame with "Name", "Score", and a new column "Pass/Fail".
#Mark "Pass" if score >= cutoff, otherwise "Fail".

# %%
#----------------------------
#Part 4: Reflection 
##----------------------------
#
#- What are the benefits of writing functions instead of repeating code?
#
#- How does using parameters make your functions more flexible?
#
#- Which was easier: writing a function with 1, 2, or 3 parameters? Why?
