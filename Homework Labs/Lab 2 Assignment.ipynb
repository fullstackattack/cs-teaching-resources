# %%
# =====================================
# Lab2: Numbers, Strings, Names, and Arrays
# =====================================
# Follow the prompts below. Write your answers as Python code
# in the cells beneath each set of instructions.


# -------------------------------
# Part 1: Strings
# -------------------------------

# 1. Concatenate three strings together using +. 
#    Be sure to include spaces where you want them to appear.

# 2. Write a string that includes an apostrophe (example: "it's").
#    Do this once with single quotes and once with double quotes.

# 3. Use indexing to print just the first letter of your name string.

# %%
# -------------------------------
# Part 2: Names 
# -------------------------------

# 4. Assign a value to quarter, then define half = 2 * quarter. 
#    Print both. 
#    Now reassign quarter to a new value. What happens to half?

# 5. Pick a “bad” variable name (like x or a1). 
#    Then pick a “good” descriptive variable name. 
#    Assign the same value to both and explain in comments 
#    which one is easier to read and why.

# 6. Try writing an expression using a variable BEFORE defining it. 
#    What error message do you see? Why?

# %%
# -------------------------------
# Part 3: Arrays 
# -------------------------------

# 7. Import numpy as np. 
#     Create an array of three temperatures in Celsius. 
#     Convert them to Fahrenheit using (9/5) * temps + 32.

# 8. Use np.diff on your array. 
#     What does the result show? 
#     How many numbers are in the result compared to the original array?

# 9. Try np.sum, np.prod, and np.sort on your array. 
#     Write a comment explaining what each function does.

# %%
# -------------------------------
# Part 4: Combining Ideas 
# -------------------------------

# 10. Write a short program that:
#       - Creates an array of ages of people in your group.
#       - Uses a function to calculate the average age.
#       - Prints out a message with the result.
