# %%
# ============================
# Lab 3: Sort, Filter, Search, and Tables
# ============================
#
# In this lab, you’ll practice basic NumPy operations:
#   - Sorting arrays
#   - Filtering with conditions
#   - Searching for values
#   - Creating and displaying tables
#
# Before starting: import NumPy (and pandas for tables)
#    import numpy as np
#    import pandas as pd
#
# ----------------------------
# Part 1: Sorting
# ----------------------------
# 1. Create a NumPy array with 5 unsorted integers, e.g. np.array([7, 2, 9, 4, 1]).
#    Use np.sort() on it. Print the original and the sorted version.
#
# 2. Sort an array of strings (e.g. ["pear", "apple", "banana"]) and
#    print the result. In a comment, explain how it sorts the strings.

# %%
# ----------------------------
# Part 2: Filtering
# ----------------------------
# 3. Create an array of numbers from 0 to 20.
#    Filter out only the even numbers. Print the filtered array. (Hint: Use modulo to determine whether a number is even or odd) 
#
# 4. From the same array, filter values greater than 10.
#
# 5. Combine conditions:
#    Filter values that are greater than 5 AND less than 15.
#
# 6. Replace all values greater than 15 with -1.
#    Print the updated array.

# %%
# ----------------------------
# Part 3: Searching
# ----------------------------
# 7. Create an array of numbers [10, 20, 30, 40, 50].
#    Use np.where() to find the indices of elements greater than 25.
#
# 8. Use those indices to print the actual values from the array.
#
# 9. Try np.searchsorted:
#     - Start with a sorted array [5, 10, 15, 20, 25].
#     - Find where 12 would be inserted.
#     - Find where 30 would be inserted.
#     - Try using side='right' and observe the difference.

# %%
# ----------------------------
# Part 4: Creating Tables
# ----------------------------
# 11. Create a NumPy array of student scores:
#     names = ["Alice", "Bob", "Carlos", "Diana"]
#     scores = [85, 92, 78, 90]
#
#     Put these into a pandas DataFrame with columns "Name" and "Score".
#     Print the table.
#
# 12. Sort the table by scores in ascending order.
#
# 13. Filter the table to show only students with scores above 80.
#
# 14. Add a new column called "Pass/Fail"
#     - Mark "Pass" if the score is >= 80
#     - Mark "Fail" if the score is < 80
#     Print the updated table.
