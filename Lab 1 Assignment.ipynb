# %%
# =====================================
# Lab 1: Expressions, Variables, and Data Types
# =====================================
# Follow the prompts below. Write your answers as Python code
# in the cells beneath each set of instructions.

# -------------------------------
# Part 1: Expressions and Evaluation
# -------------------------------

# 1. Write three different arithmetic expressions. 
#    Before running the code, PREDICT the result in a comment. 
#    Then run and check.

# 2. Try mixing integers and decimals (e.g., 3 + 4.5).
#    What type of number is returned? Use type() to verify.

# 3. Write an expression that uses parentheses to change 
#    the order of operations.

# %%
# -------------------------------
# Part 2: Variables (Names)
# -------------------------------

# 4. Assign the number of students in your class to a variable.
#    Assign the number of computers available to another variable. You can make these numbers up. 
#    Write an expression that calculates how many students 
#    will need to share a computer.

# 5. Try reassigning a variable to a new value. 
#    What happens to the old value?

# 6. Write an expression using a variable BEFORE defining it. 
#    What error do you see? Why?

# %%
# -------------------------------
# Part 3: Data Types
# -------------------------------

# 7. Create variables for:
#    - Your name (string)
#    - Your age (integer)
#    - Your GPA (float)
#    - Whether you like pizza (boolean)
#    Use print() to display each one.

# 8. Convert your age into a string and concatenate it with your name 
#    in a sentence. Example: "My name is ___ and I am ___ years old."

# 9. Convert your GPA into an integer. What do you notice?

# %%
# -------------------------------
# Part 4: Combining Ideas
# -------------------------------

# 10. Write a short program that:
#     - Asks the user for their name and age (Hint: use input() and store questions in separate variables).
#     - Calculates what year they will turn 100.
#     - Prints out a friendly message with the result.

# 11. Challenge: (Optional, but recommended) 
#     - Create a variable for the price of an item and the amount of money a customer has.
#     - Write code that prints whether the customer can afford the item, and if so, how much change they get.
